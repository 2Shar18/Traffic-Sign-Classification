# %%
#Necessary dependency import
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score
np.random.seed(42)

from matplotlib import style
style.use('fivethirtyeight')

# %%
#Defining the dataset folder
data_dir = 'GTSRB_data'
train_path = 'GTSRB_data/Train'
test_path = 'GTSRB_data/Test'

# Resizing the images to 30x30x3
IMG_HEIGHT = 30
IMG_WIDTH = 30
channels = 3

# %%
NUM_CATEGORIES = len(os.listdir(train_path))
NUM_CATEGORIES
# Out:
# 43

# %%
# Label Overview
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %%
folders = os.listdir(train_path)

train_number = []
class_num = []

for folder in folders:
    train_files = os.listdir(train_path + '/' + folder)
    train_number.append(len(train_files))
    class_num.append(classes[int(folder)])
    
# Sorting the dataset on the basis of number of images in each class
zipped_lists = zip(train_number, class_num)
sorted_pairs = sorted(zipped_lists)
tuples = zip(*sorted_pairs)
train_number, class_num = [ list(tuple) for tuple in  tuples]

# Plotting the number of images in each class
plt.figure(figsize=(21,10))  
plt.bar(class_num, train_number)
plt.xticks(class_num, rotation='vertical')
plt.show()

# %%
# Visualizing 25 random images from test data
import random
from matplotlib.image import imread

test = pd.read_csv(data_dir + '/Test.csv')
imgs = test["Path"].values

plt.figure(figsize=(25,25))

for i in range(1,26):
    plt.subplot(5,5,i)
    random_img_path = data_dir + '/' + random.choice(imgs)
    rand_img = imread(random_img_path)
    plt.imshow(rand_img)
    plt.grid(b=None)
    plt.xlabel(rand_img.shape[1], fontsize = 20)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 20)#height of image

# %%
image_data = []
image_labels = []

for i in range(NUM_CATEGORIES):
    path = data_dir + '/Train/' + str(i)
    images = os.listdir(path)

    for img in images:
        try:
            image = cv2.imread(path + '/' + img)
            image_fromarray = Image.fromarray(image, 'RGB')
            resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
            image_data.append(np.array(resize_image))
            image_labels.append(i)
        except:
            print("Error in " + img)

# Changing the list to numpy array
image_data = np.array(image_data)
image_labels = np.array(image_labels)

print(image_data.shape, image_labels.shape)
# Out:
# (39209, 30, 30, 3) (39209,)

# %%
#Randomizing the data
shuffle_indexes = np.arange(image_data.shape[0])
np.random.shuffle(shuffle_indexes)
image_data = image_data[shuffle_indexes]
image_labels = image_labels[shuffle_indexes]

# %%
#Splitting to Training and Validation sets
X_train, X_val, y_train, y_val = train_test_split(image_data, image_labels, test_size=0.3, random_state=42, shuffle=True)

X_train = X_train/255 
X_val = X_val/255

print("X_train.shape", X_train.shape)
print("X_valid.shape", X_val.shape)
print("y_train.shape", y_train.shape)
print("y_valid.shape", y_val.shape)
# Out:
# X_train.shape (27446, 30, 30, 3)
# X_valid.shape (11763, 30, 30, 3)
# y_train.shape (27446,)
# y_valid.shape (11763,)

# %%
#Making labels categorical
y_train = keras.utils.to_categorical(y_train, NUM_CATEGORIES)
y_val = keras.utils.to_categorical(y_val, NUM_CATEGORIES)

print(y_train.shape)
print(y_val.shape)
# Out:
# (27446, 43)
# (11763, 43)

# %%
#MLP Model
model = keras.models.Sequential([
    keras.layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, channels)),
    keras.layers.Flatten(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(43, activation='softmax'),
])

# %%
#Defining the Hyperparameters
lr = 0.001
epochs = 30

opt = Adam(learning_rate=lr, decay=lr / (epochs * 0.5))
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 2700)              0
#
#  dense (Dense)               (None, 256)               691456
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 43)                5547
#
# =================================================================
# Total params: 729,899
# Trainable params: 729,899
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Fitting the model (Training)
aug = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.15,
    horizontal_flip=False,
    vertical_flip=False,
    fill_mode="nearest")

history = model.fit(aug.flow(X_train, y_train, batch_size=32), epochs=epochs, validation_data=(X_val, y_val))
# Out:
# Epoch 1/30
# 858/858 [==============================] - 15s 16ms/step - loss: 2.7680 - accuracy: 0.2496 - val_loss: 1.9634 - val_accuracy: 0.4285
# Epoch 2/30
# 858/858 [==============================] - 13s 15ms/step - loss: 2.0730 - accuracy: 0.3870 - val_loss: 1.5036 - val_accuracy: 0.5319
# Epoch 3/30
# 858/858 [==============================] - 12s 14ms/step - loss: 1.8098 - accuracy: 0.4528 - val_loss: 1.3464 - val_accuracy: 0.5658
# Epoch 4/30
# 858/858 [==============================] - 13s 15ms/step - loss: 1.6629 - accuracy: 0.4958 - val_loss: 1.1702 - val_accuracy: 0.6431
# Epoch 5/30
# 858/858 [==============================] - 21s 25ms/step - loss: 1.5285 - accuracy: 0.5345 - val_loss: 1.0402 - val_accuracy: 0.6939
# Epoch 6/30
# 858/858 [==============================] - 11s 13ms/step - loss: 1.4361 - accuracy: 0.5662 - val_loss: 0.9400 - val_accuracy: 0.7153
# Epoch 7/30
# 858/858 [==============================] - 11s 12ms/step - loss: 1.3233 - accuracy: 0.5958 - val_loss: 0.8834 - val_accuracy: 0.7352
# Epoch 8/30
# 858/858 [==============================] - 11s 12ms/step - loss: 1.2614 - accuracy: 0.6197 - val_loss: 0.7813 - val_accuracy: 0.7717
# Epoch 9/30
# 858/858 [==============================] - 11s 13ms/step - loss: 1.1871 - accuracy: 0.6343 - val_loss: 0.7920 - val_accuracy: 0.7627
# Epoch 10/30
# 858/858 [==============================] - 11s 13ms/step - loss: 1.1454 - accuracy: 0.6506 - val_loss: 0.7136 - val_accuracy: 0.7925
# Epoch 11/30
# 858/858 [==============================] - 11s 13ms/step - loss: 1.1001 - accuracy: 0.6676 - val_loss: 0.6744 - val_accuracy: 0.7812
# Epoch 12/30
# 858/858 [==============================] - 10s 12ms/step - loss: 1.0395 - accuracy: 0.6819 - val_loss: 0.7031 - val_accuracy: 0.7780
# Epoch 13/30
# 858/858 [==============================] - 10s 11ms/step - loss: 1.0058 - accuracy: 0.6954 - val_loss: 0.5924 - val_accuracy: 0.8224
# Epoch 14/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.9688 - accuracy: 0.7099 - val_loss: 0.5752 - val_accuracy: 0.8340
# Epoch 15/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.9397 - accuracy: 0.7137 - val_loss: 0.5578 - val_accuracy: 0.8372
# Epoch 16/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.8985 - accuracy: 0.7252 - val_loss: 0.5346 - val_accuracy: 0.8433
# Epoch 17/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.8779 - accuracy: 0.7355 - val_loss: 0.5280 - val_accuracy: 0.8443
# Epoch 18/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.8445 - accuracy: 0.7450 - val_loss: 0.4985 - val_accuracy: 0.8549
# Epoch 19/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.8393 - accuracy: 0.7448 - val_loss: 0.5264 - val_accuracy: 0.8406
# Epoch 20/30
# 858/858 [==============================] - 11s 12ms/step - loss: 0.7991 - accuracy: 0.7553 - val_loss: 0.4768 - val_accuracy: 0.8617
# Epoch 21/30
# 858/858 [==============================] - 10s 11ms/step - loss: 0.8020 - accuracy: 0.7572 - val_loss: 0.4638 - val_accuracy: 0.8678
# Epoch 22/30
# 858/858 [==============================] - 10s 11ms/step - loss: 0.7806 - accuracy: 0.7644 - val_loss: 0.5045 - val_accuracy: 0.8478
# Epoch 23/30
# 858/858 [==============================] - 10s 11ms/step - loss: 0.7626 - accuracy: 0.7724 - val_loss: 0.4384 - val_accuracy: 0.8779
# Epoch 24/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.7529 - accuracy: 0.7748 - val_loss: 0.4602 - val_accuracy: 0.8708
# Epoch 25/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.7566 - accuracy: 0.7730 - val_loss: 0.4277 - val_accuracy: 0.8713
# Epoch 26/30
# 858/858 [==============================] - 10s 12ms/step - loss: 0.7254 - accuracy: 0.7792 - val_loss: 0.4030 - val_accuracy: 0.8823
# Epoch 27/30
# 858/858 [==============================] - 12s 14ms/step - loss: 0.7127 - accuracy: 0.7848 - val_loss: 0.4012 - val_accuracy: 0.8836
# Epoch 28/30
# 858/858 [==============================] - 30s 35ms/step - loss: 0.7102 - accuracy: 0.7859 - val_loss: 0.4124 - val_accuracy: 0.8823
# Epoch 29/30
# 858/858 [==============================] - 26s 30ms/step - loss: 0.6913 - accuracy: 0.7893 - val_loss: 0.3948 - val_accuracy: 0.8806
# Epoch 30/30
# 858/858 [==============================] - 28s 33ms/step - loss: 0.6666 - accuracy: 0.8001 - val_loss: 0.3799 - val_accuracy: 0.8945

# %%
#Accuracy chart
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
#Test data accuracy
test = pd.read_csv(data_dir + '/Test.csv')

labels = test["ClassId"].values
imgs = test["Path"].values

data =[]

for img in imgs:
    try:
        image = cv2.imread(data_dir + '/' +img)
        image_fromarray = Image.fromarray(image, 'RGB')
        resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
        data.append(np.array(resize_image))
    except:
        print("Error in " + img)
X_test = np.array(data)
X_test = X_test/255

predict_x = model.predict(X_test)
pred = np.argmax(predict_x,axis=1)

#Accuracy with the test data
print('Test Data accuracy: ',accuracy_score(labels, pred)*100)
# Out:
# Test Data accuracy:  71.60728424386382

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(labels, pred)

# %%
#Confusion Matrix
import seaborn as sns
df_cm = pd.DataFrame(cf, index = classes,  columns = classes)
plt.figure(figsize = (20,20))
sns.heatmap(df_cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
#Classification Report
from sklearn.metrics import classification_report

print(classification_report(labels, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.03      0.02      0.02        60
#            1       0.62      0.56      0.59       720
#            2       0.50      0.50      0.50       750
#            3       0.62      0.75      0.68       450
#            4       0.77      0.56      0.65       660
#            5       0.46      0.61      0.52       630
#            6       0.77      0.41      0.53       150
#            7       0.61      0.59      0.60       450
#            8       0.51      0.60      0.55       450
#            9       0.95      0.81      0.87       480
#           10       0.85      0.95      0.90       660
#           11       0.75      0.77      0.76       420
#           12       0.98      0.90      0.94       690
#           13       0.96      0.95      0.96       720
#           14       0.90      0.99      0.94       270
#           15       0.88      0.91      0.89       210
#           16       0.99      0.99      0.99       150
#           17       0.99      0.75      0.85       360
#           18       0.82      0.56      0.67       390
#           19       0.53      0.65      0.59        60
#           20       0.31      0.32      0.32        90
#           21       0.09      0.06      0.07        90
#           22       0.76      0.76      0.76       120
#           23       0.14      0.21      0.17       150
#           24       0.32      0.10      0.15        90
#           25       0.83      0.72      0.77       480
#           26       0.81      0.83      0.82       180
#           27       0.26      0.32      0.29        60
#           28       0.35      0.51      0.41       150
#           29       0.79      0.72      0.76        90
#           30       0.37      0.39      0.38       150
#           31       0.73      0.83      0.78       270
#           32       0.50      0.92      0.65        60
#           33       0.77      0.99      0.87       210
#           34       0.82      0.98      0.89       120
#           35       0.89      0.78      0.83       390
#           36       0.87      0.74      0.80       120
#           37       0.79      0.75      0.77        60
#           38       0.88      0.98      0.93       690
#           39       0.65      0.67      0.66        90
#           40       0.91      0.54      0.68        90
#           41       0.69      0.70      0.69        60
#           42       0.40      0.56      0.46        90
#
#     accuracy                           0.72     12630
#    macro avg       0.66      0.66      0.65     12630
# weighted avg       0.73      0.72      0.72     12630

# %%
#Predictions on Test Data
plt.figure(figsize = (25, 25))

start_index = 0
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    prediction = pred[start_index + i]
    actual = labels[start_index + i]
    col = 'g'
    if prediction != actual:
        col = 'r'
    plt.xlabel('Actual={} || Pred={}'.format(actual, prediction), color = col)
    plt.imshow(X_test[start_index + i])
plt.show()
print(classes)
# Out:
# {0: 'Speed limit (20km/h)', 1: 'Speed limit (30km/h)', 2: 'Speed limit (50km/h)', 3: 'Speed limit (60km/h)', 4: 'Speed limit (70km/h)', 5: 'Speed limit (80km/h)', 6: 'End of speed limit (80km/h)', 7: 'Speed limit (100km/h)', 8: 'Speed limit (120km/h)', 9: 'No passing', 10: 'No passing veh over 3.5 tons', 11: 'Right-of-way at intersection', 12: 'Priority road', 13: 'Yield', 14: 'Stop', 15: 'No vehicles', 16: 'Veh > 3.5 tons prohibited', 17: 'No entry', 18: 'General caution', 19: 'Dangerous curve left', 20: 'Dangerous curve right', 21: 'Double curve', 22: 'Bumpy road', 23: 'Slippery road', 24: 'Road narrows on the right', 25: 'Road work', 26: 'Traffic signals', 27: 'Pedestrians', 28: 'Children crossing', 29: 'Bicycles crossing', 30: 'Beware of ice/snow', 31: 'Wild animals crossing', 32: 'End speed + passing limits', 33: 'Turn right ahead', 34: 'Turn left ahead', 35: 'Ahead only', 36: 'Go straight or right', 37: 'Go straight or left', 38: 'Keep right', 39: 'Keep left', 40: 'Roundabout mandatory', 41: 'End of no passing', 42: 'End no passing veh > 3.5 tons'}
